# %% [markdown]
# <a href="https://colab.research.google.com/github/ZHAbotorabi/TTS/blob/main/Text_to_Speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install gTTS if not already installed
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
# your text
text = "You will hear a student booking a library room. I would like a small study room at 3 p.m."

# %%
# create TTS object and save mp3
tts = gTTS(text=text, lang='en')
tts.save("sample_listening_form_completion.mp3")
print("Audio saved as sample_listening_form_completion.mp3")
# Out:
# Audio saved as sample_listening_form_completion.mp3

# %%
# play it directly in the notebook
Audio("sample_listening_form_completion.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# https://voicemaker.in/
